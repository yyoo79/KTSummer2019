# %% [markdown]
# # 선형회귀(Linear Regression)

# %% [markdown]
# > 아래와 같이 하루 노동 시간에 따른 매출량 데이터가 있을 때, '**8시간**' 일했을 때는 매출이 얼마나 될 지 추측하는 프로그램을 작성하세요.

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/yyoo79/KTSummer2019/master/ModuleTFU1-R-pic1.PNG)

# %%
# tensorflow를 import합니다.
import

#xData와 yData를 만듭니다.
xData = 
yData =

# %%
# W와 b를 Variable로 만듭니다. 랜덤으로 숫자를 지정합니다.
W = 
b = 

# X, Y 만 이름의 placeholder를 만듭니다. type은 float32를 사용합니다.
X = 
Y = 

# H의 공식을 만듭니다.
H =

# %%
# cost의 공식을 reduce_mean함수를 사용하여 만듭니다.
cost = 

# 변수 a는 점프의 크기입니다. 0.01로 지정합니다.
a =

# %%
# GradientDescentOptimizer를 만듭니다. 
# 이함수는 점프의 크기를 parameter로 받습니다.
optimizer = 

# 아까 만든 cost의 공식을 사용하여 train를 만듭니다.
train =

# %%
# 변수들을 initialize해줍니다.
init = 

# Session를 만들고 initialzed된 변수를 sess를 사용해 run합니다
sess = 
sess.run()

# %%
# 5000번 training을 시작합니다.
# loop으로 돌리면 feed_dict로 값을 지정해 줍니다.
# 매 500번마다 cost, xData, yData, W, b 값을 출력합니다.
# 마지막으로 H 값을 출력합니다.
for i in range():
    sess.run()
    if i % 500 == 0:
        print()
print ()
